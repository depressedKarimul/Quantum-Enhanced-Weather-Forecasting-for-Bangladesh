# %%
import requests

url = "https://power.larc.nasa.gov/api/temporal/daily/point"
params = {
    "parameters": "T2M,T2M_MAX,T2M_MIN,RH2M,PRECTOTCORR,WS2M",
    "community": "RE",
    "longitude": 90.4125,
    "latitude": 23.8103,
    "start": "19810101",  # 1980 → 1981 করলাম
    "end": "20260514",
    "format": "CSV"
}

response = requests.get(url, params=params, timeout=180)

with open("bangladesh_weather_1981_2026.csv", "wb") as f:
    f.write(response.content)

print("Status:", response.status_code)
print("Done! File saved.")
# Out:
# Status: 200
# Done! File saved.

# %%
import pennylane as qml
import torch
import sklearn
import pandas as pd
import numpy as np

print("PennyLane:", qml.__version__)
print("PyTorch:", torch.__version__)
print("✅ সব ঠিক আছে!")
# Out:
# C:\Users\User\.conda\envs\quantum\lib\site-packages\pennylane\__init__.py:21: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# PennyLane: 0.29.1
# PyTorch: 2.11.0+cu128
# ✅ সব ঠিক আছে!

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "Not found")
# Out:
# CUDA available: True
# GPU: NVIDIA GeForce RTX 5050

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "Not found")
# Out:
# CUDA available: True
# GPU: NVIDIA GeForce RTX 5050

# %%
pip install pennylane-lightning
# Out:
# Requirement already satisfied: pennylane-lightning in c:\users\user\.conda\envs\quantum\lib\site-packages (0.30.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pennylane>=0.28 in c:\users\user\.conda\envs\quantum\lib\site-packages (from pennylane-lightning) (0.29.1)
# Requirement already satisfied: numpy<1.24 in c:\users\user\.conda\envs\quantum\lib\site-packages (from pennylane>=0.28->pennylane-lightning) (1.23.5)
# Requirement already satisfied: scipy in c:\users\user\.conda\envs\quantum\lib\site-packages (from pennylane>=0.28->pennylane-lightning) (1.15.3)
# Requirement already satisfied: networkx in c:\users\user\.conda\envs\quantum\lib\site-packages (from pennylane>=0.28->pennylane-lightning) (3.4.2)
# Requirement already satisfied: retworkx in c:\users\user\.conda\envs\quantum\lib\site-packages (from pennylane>=0.28->pennylane-lightning) (0.17.1)
# Requirement already satisfied: autograd in c:\users\user\.conda\envs\quantum\lib\site-packages (from pennylane>=0.28->pennylane-lightning) (1.8.0)
# Requirement already satisfied: toml in c:\users\user\.conda\envs\quantum\lib\site-packages (from pennylane>=0.28->pennylane-lightning) (0.10.2)
# Requirement already satisfied: appdirs in c:\users\user\.conda\envs\quantum\lib\site-packages (from pennylane>=0.28->pennylane-lightning) (1.4.4)
# Requirement already satisfied: semantic-version>=2.7 in c:\users\user\.conda\envs\quantum\lib\site-packages (from pennylane>=0.28->pennylane-lightning) (2.10.0)
# Requirement already satisfied: autoray>=0.3.1 in c:\users\user\.conda\envs\quantum\lib\site-packages (from pennylane>=0.28->pennylane-lightning) (0.7.2)
# Requirement already satisfied: cachetools in c:\users\user\.conda\envs\quantum\lib\site-packages (from pennylane>=0.28->pennylane-lightning) (7.1.1)
# Requirement already satisfied: requests in c:\users\user\.conda\envs\quantum\lib\site-packages (from pennylane>=0.28->pennylane-lightning) (2.34.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\.conda\envs\quantum\lib\site-packages (from requests->pennylane>=0.28->pennylane-lightning) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\.conda\envs\quantum\lib\site-packages (from requests->pennylane>=0.28->pennylane-lightning) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\user\.conda\envs\quantum\lib\site-packages (from requests->pennylane>=0.28->pennylane-lightning) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\user\.conda\envs\quantum\lib\site-packages (from requests->pennylane>=0.28->pennylane-lightning) (2026.4.22)
# Requirement already satisfied: rustworkx in c:\users\user\.conda\envs\quantum\lib\site-packages (from retworkx->pennylane>=0.28->pennylane-lightning) (0.17.1)

# %%
import pennylane as qml

n_qubits = 6
dev = qml.device('lightning.qubit', wires=n_qubits)
print("Lightning device ready! ✅")
# Out:
# Lightning device ready! ✅
